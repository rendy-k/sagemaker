# %% [markdown]
# # Multiple Models by Hyperparameters
#
# ## Training models
#
# Previous activity: preparing and splitting data

# %%
import numpy as np
import pandas as pd
import sagemaker
from sagemaker import get_execution_role
from sagemaker.serializers import CSVSerializer

# %%
# Set the file directories
bucket_name = "sagemaker-loan-classification"
prefix = "xgboost"

# Set input and output paths for sagemaker
input_train = sagemaker.TrainingInput(
    s3_data=f"s3://{bucket_name}/{prefix}/train", content_type="csv")
input_test = sagemaker.TrainingInput(
    s3_data=f"s3://{bucket_name}/{prefix}/test", content_type="csv")
output_path = f"s3://{bucket_name}/{prefix}/saved_model"

# %%
# Build the estimator
def xgboost_fit_param(model_name, hyperparameters, use_spot_instances=False, max_run=3200, max_wait=None):
    name = f"xgboost-loan-{model_name}"
    print(f"____Running {name}")

    # Set checkpoint
    checkpoint = None
    if use_spot_instances == True:
        checkpoint = f"s3://{bucket_name}/{prefix}/checkpoints/{name}"
        print(f"___The checkpoint is saved to: {checkpoint}")
        max_wait = 7600

    # Set the container based on the version
    container = sagemaker.image_uris.retrieve("xgboost",
                                              sagemaker.Session().boto_region_name,
                                              version="1.2-2")

    xgb = sagemaker.estimator.Estimator(
        image_uri=container,
        role=sagemaker.get_execution_role(),
        instance_count=1,
        instance_type="ml.m5.xlarge",
        output_path=output_path,
        sagemaker_session=sagemaker.Session(),
        checkpoint_s3_uri=checkpoint,
        use_spot_instances=use_spot_instances,
        max_run=max_run,
        max_wait=max_wait,
        base_job_name=name,
        hyperparameters=hyperparameters,
    )

    # Fit the model
    xgb.fit(
        {
            "train": input_train,
            "validation": input_test
        }
    )

    print(f"____Finish running {xgb.latest_training_job.name}")

# %%
# Set the hyperparameters
hyperparameter_1 = {
    "colsample_bytree": 0.478,
    "gamma": 2.387,
    "eta": 0.175,
    "max_depth": 15,
    "min_child_weight": 7,
    "num_round": 86,
    "subsample": 0.80,
    "num_class": 2,
    "objective": "multi:softmax",
}

hyperparameter_2 = {
    "colsample_bytree": 0.1,
    "gamma": 0,
    "eta": 0.01,
    "max_depth": 3,
    "min_child_weight": 3,
    "num_round": 89,
    "subsample": 1,
    "num_class": 2,
    "objective": "multi:softmax",
}

# %%
xgboost_fit_param(model_name="model-1", hyperparameters=hyperparameter_1)
# Out:
# ____Running xgboost-loan-model-1
# 2022-01-29 12:01:20 Starting - Starting the training job...
# 2022-01-29 12:01:22 Starting - Launching requested ML instancesProfilerReport-1643457680: InProgress
# ...
# 2022-01-29 12:02:15 Starting - Preparing the instances for training.........
# 2022-01-29 12:03:50 Downloading - Downloading input data
# 2022-01-29 12:03:50 Training - Downloading the training image.....[2022-01-29 12:04:26.974 ip-10-0-145-53.ap-southeast-1.compute.internal:1 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-01-29:12:04:27:INFO] Imported framework sagemaker_xgboost_container.training
# [2022-01-29:12:04:27:INFO] Failed to parse hyperparameter objective value multi:softmax to Json.
# Returning the value itself
# [2022-01-29:12:04:27:INFO] No GPUs detected (normal if no gpus installed)
# [2022-01-29:12:04:27:INFO] Running XGBoost Sagemaker in algorithm mode
# [2022-01-29:12:04:27:INFO] Determined delimiter of CSV input is ','
# [2022-01-29:12:04:27:INFO] Determined delimiter of CSV input is ','
# [2022-01-29:12:04:27:INFO] Determined delimiter of CSV input is ','
# [2022-01-29:12:04:27:INFO] Determined delimiter of CSV input is ','
# [2022-01-29:12:04:27:INFO] Single node training.
# [2022-01-29:12:04:27:INFO] Train matrix has 384 rows and 13 columns
# [2022-01-29:12:04:27:INFO] Validation matrix has 96 rows
# [0]#011train-merror:0.17708#011validation-merror:0.25000
# [1]#011train-merror:0.23698#011validation-merror:0.28125
# [2]#011train-merror:0.18750#011validation-merror:0.25000
# [3]#011train-merror:0.17708#011validation-merror:0.25000
# [4]#011train-merror:0.17708#011validation-merror:0.25000
# [5]#011train-merror:0.17708#011validation-merror:0.25000
# [6]#011train-merror:0.17708#011validation-merror:0.25000
# [7]#011train-merror:0.17708#011validation-merror:0.25000
# [8]#011train-merror:0.17708#011validation-merror:0.25000
# [9]#011train-merror:0.17708#011validation-merror:0.25000
# [10]#011train-merror:0.17708#011validation-merror:0.25000
# [11]#011train-merror:0.17708#011validation-merror:0.25000
# [12]#011train-merror:0.17708#011validation-merror:0.25000
# [13]#011train-merror:0.17708#011validation-merror:0.25000
# [14]#011train-merror:0.17708#011validation-merror:0.25000
# [15]#011train-merror:0.17708#011validation-merror:0.25000
# [16]#011train-merror:0.17708#011validation-merror:0.25000
# [17]#011train-merror:0.17708#011validation-merror:0.25000
# [18]#011train-merror:0.17708#011validation-merror:0.25000
# [19]#011train-merror:0.17708#011validation-merror:0.25000
# [20]#011train-merror:0.17708#011validation-merror:0.25000
# [21]#011train-merror:0.17708#011validation-merror:0.25000
# [22]#011train-merror:0.17708#011validation-merror:0.25000
# [23]#011train-merror:0.17708#011validation-merror:0.25000
# [24]#011train-merror:0.17708#011validation-merror:0.25000
# [25]#011train-merror:0.17708#011validation-merror:0.25000
# [26]#011train-merror:0.17708#011validation-merror:0.25000
# [27]#011train-merror:0.17708#011validation-merror:0.25000
# [28]#011train-merror:0.17708#011validation-merror:0.25000
# [29]#011train-merror:0.17708#011validation-merror:0.25000
# [30]#011train-merror:0.17708#011validation-merror:0.25000
# [31]#011train-merror:0.17708#011validation-merror:0.25000
# [32]#011train-merror:0.17708#011validation-merror:0.25000
# [33]#011train-merror:0.17708#011validation-merror:0.25000
# [34]#011train-merror:0.17708#011validation-merror:0.25000
# [35]#011train-merror:0.17708#011validation-merror:0.25000
# [36]#011train-merror:0.17708#011validation-merror:0.25000
# [37]#011train-merror:0.17708#011validation-merror:0.25000
# [38]#011train-merror:0.17708#011validation-merror:0.25000
# [39]#011train-merror:0.17708#011validation-merror:0.25000
# [40]#011train-merror:0.17708#011validation-merror:0.25000
# [41]#011train-merror:0.17708#011validation-merror:0.25000
# [42]#011train-merror:0.17708#011validation-merror:0.25000
# [43]#011train-merror:0.17708#011validation-merror:0.25000
# [44]#011train-merror:0.17708#011validation-merror:0.25000
# [45]#011train-merror:0.17708#011validation-merror:0.25000
# [46]#011train-merror:0.17708#011validation-merror:0.25000
# [47]#011train-merror:0.17708#011validation-merror:0.25000
# [48]#011train-merror:0.17708#011validation-merror:0.25000
# [49]#011train-merror:0.17708#011validation-merror:0.25000
# [50]#011train-merror:0.17708#011validation-merror:0.25000
# [51]#011train-merror:0.17708#011validation-merror:0.25000
# [52]#011train-merror:0.17708#011validation-merror:0.25000
# [53]#011train-merror:0.17708#011validation-merror:0.25000
# [54]#011train-merror:0.17708#011validation-merror:0.25000
# [55]#011train-merror:0.17708#011validation-merror:0.25000
# [56]#011train-merror:0.17708#011validation-merror:0.25000
# [57]#011train-merror:0.17708#011validation-merror:0.25000
# [58]#011train-merror:0.17708#011validation-merror:0.25000
# [59]#011train-merror:0.17708#011validation-merror:0.25000
# [60]#011train-merror:0.17708#011validation-merror:0.25000
# [61]#011train-merror:0.17708#011validation-merror:0.25000
# [62]#011train-merror:0.17708#011validation-merror:0.25000
# [63]#011train-merror:0.17708#011validation-merror:0.25000
# [64]#011train-merror:0.17708#011validation-merror:0.25000
# [65]#011train-merror:0.17708#011validation-merror:0.25000
# [66]#011train-merror:0.17708#011validation-merror:0.25000
# [67]#011train-merror:0.17708#011validation-merror:0.25000
# [68]#011train-merror:0.17708#011validation-merror:0.25000
# [69]#011train-merror:0.17708#011validation-merror:0.25000
# [70]#011train-merror:0.17708#011validation-merror:0.25000
# [71]#011train-merror:0.17708#011validation-merror:0.25000
# [72]#011train-merror:0.17708#011validation-merror:0.25000
# [73]#011train-merror:0.17708#011validation-merror:0.25000
# [74]#011train-merror:0.17708#011validation-merror:0.25000
# [75]#011train-merror:0.17708#011validation-merror:0.25000
# [76]#011train-merror:0.17708#011validation-merror:0.25000
# [77]#011train-merror:0.17708#011validation-merror:0.25000
# [78]#011train-merror:0.17708#011validation-merror:0.25000
# [79]#011train-merror:0.17708#011validation-merror:0.25000
# [80]#011train-merror:0.17708#011validation-merror:0.25000
# [81]#011train-merror:0.17708#011validation-merror:0.25000
# [82]#011train-merror:0.17708#011validation-merror:0.25000
# [83]#011train-merror:0.17708#011validation-merror:0.25000
# [84]#011train-merror:0.17708#011validation-merror:0.25000
# [85]#011train-merror:0.17708#011validation-merror:0.25000
#
# 2022-01-29 12:04:51 Uploading - Uploading generated training model
# 2022-01-29 12:04:51 Completed - Training job completed
# Training seconds: 72
# Billable seconds: 72
# ____Finish running xgboost-loan-model-1-2022-01-29-12-01-20-372

# %%
xgboost_fit_param(model_name="model-2", hyperparameters=hyperparameter_2)
# Out:
# ____Running xgboost-loan-model-2
# 2022-01-29 12:05:31 Starting - Starting the training job...
# 2022-01-29 12:05:54 Starting - Launching requested ML instancesProfilerReport-1643457931: InProgress
# ...
# 2022-01-29 12:06:26 Starting - Preparing the instances for training.........
# 2022-01-29 12:07:54 Downloading - Downloading input data...
# 2022-01-29 12:08:14 Training - Downloading the training image..[2022-01-29 12:08:43.990 ip-10-0-217-112.ap-southeast-1.compute.internal:1 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-01-29:12:08:44:INFO] Imported framework sagemaker_xgboost_container.training
# [2022-01-29:12:08:44:INFO] Failed to parse hyperparameter objective value multi:softmax to Json.
# Returning the value itself
# [2022-01-29:12:08:44:INFO] No GPUs detected (normal if no gpus installed)
# [2022-01-29:12:08:44:INFO] Running XGBoost Sagemaker in algorithm mode
# [2022-01-29:12:08:44:INFO] Determined delimiter of CSV input is ','
# [2022-01-29:12:08:44:INFO] Determined delimiter of CSV input is ','
# [2022-01-29:12:08:44:INFO] Determined delimiter of CSV input is ','
# [2022-01-29:12:08:44:INFO] Determined delimiter of CSV input is ','
# [2022-01-29:12:08:44:INFO] Single node training.
# [2022-01-29:12:08:44:INFO] Train matrix has 384 rows and 13 columns
# [2022-01-29:12:08:44:INFO] Validation matrix has 96 rows
# [0]#011train-merror:0.31771#011validation-merror:0.28125
# [1]#011train-merror:0.31510#011validation-merror:0.28125
# [2]#011train-merror:0.31510#011validation-merror:0.28125
# [3]#011train-merror:0.31510#011validation-merror:0.28125
# [4]#011train-merror:0.31510#011validation-merror:0.28125
# [5]#011train-merror:0.31510#011validation-merror:0.28125
# [6]#011train-merror:0.31510#011validation-merror:0.28125
# [7]#011train-merror:0.31510#011validation-merror:0.28125
# [8]#011train-merror:0.31510#011validation-merror:0.28125
# [9]#011train-merror:0.31510#011validation-merror:0.28125
# [10]#011train-merror:0.31510#011validation-merror:0.28125
# [11]#011train-merror:0.31510#011validation-merror:0.28125
# [12]#011train-merror:0.31510#011validation-merror:0.28125
# [13]#011train-merror:0.31510#011validation-merror:0.28125
# [14]#011train-merror:0.31510#011validation-merror:0.28125
# [15]#011train-merror:0.31510#011validation-merror:0.28125
# [16]#011train-merror:0.31510#011validation-merror:0.28125
# [17]#011train-merror:0.31510#011validation-merror:0.28125
# [18]#011train-merror:0.31510#011validation-merror:0.28125
# [19]#011train-merror:0.31510#011validation-merror:0.28125
# [20]#011train-merror:0.31510#011validation-merror:0.28125
# [21]#011train-merror:0.31510#011validation-merror:0.28125
# [22]#011train-merror:0.31510#011validation-merror:0.28125
# [23]#011train-merror:0.31510#011validation-merror:0.28125
# [24]#011train-merror:0.31510#011validation-merror:0.28125
# [25]#011train-merror:0.31510#011validation-merror:0.28125
# [26]#011train-merror:0.31510#011validation-merror:0.28125
# [27]#011train-merror:0.31510#011validation-merror:0.28125
# [28]#011train-merror:0.31510#011validation-merror:0.28125
# [29]#011train-merror:0.31510#011validation-merror:0.28125
# [30]#011train-merror:0.31510#011validation-merror:0.28125
# [31]#011train-merror:0.31510#011validation-merror:0.28125
# [32]#011train-merror:0.31510#011validation-merror:0.28125
# [33]#011train-merror:0.31510#011validation-merror:0.28125
# [34]#011train-merror:0.31510#011validation-merror:0.28125
# [35]#011train-merror:0.31510#011validation-merror:0.28125
# [36]#011train-merror:0.31510#011validation-merror:0.28125
# [37]#011train-merror:0.31510#011validation-merror:0.28125
# [38]#011train-merror:0.31510#011validation-merror:0.28125
# [39]#011train-merror:0.31510#011validation-merror:0.28125
# [40]#011train-merror:0.31510#011validation-merror:0.28125
# [41]#011train-merror:0.31510#011validation-merror:0.28125
# [42]#011train-merror:0.31510#011validation-merror:0.28125
# [43]#011train-merror:0.31510#011validation-merror:0.28125
# [44]#011train-merror:0.31510#011validation-merror:0.28125
# [45]#011train-merror:0.31510#011validation-merror:0.28125
# [46]#011train-merror:0.31510#011validation-merror:0.28125
# [47]#011train-merror:0.31510#011validation-merror:0.28125
# [48]#011train-merror:0.31510#011validation-merror:0.28125
# [49]#011train-merror:0.31510#011validation-merror:0.28125
# [50]#011train-merror:0.31510#011validation-merror:0.28125
# [51]#011train-merror:0.31510#011validation-merror:0.28125
# [52]#011train-merror:0.31510#011validation-merror:0.28125
# [53]#011train-merror:0.31510#011validation-merror:0.28125
# [54]#011train-merror:0.31510#011validation-merror:0.28125
# [55]#011train-merror:0.31510#011validation-merror:0.28125
# [56]#011train-merror:0.31510#011validation-merror:0.28125
# [57]#011train-merror:0.31510#011validation-merror:0.28125
# [58]#011train-merror:0.31510#011validation-merror:0.28125
# [59]#011train-merror:0.31510#011validation-merror:0.28125
# [60]#011train-merror:0.31510#011validation-merror:0.28125
# [61]#011train-merror:0.31510#011validation-merror:0.28125
# [62]#011train-merror:0.31510#011validation-merror:0.28125
# [63]#011train-merror:0.31510#011validation-merror:0.28125
# [64]#011train-merror:0.31510#011validation-merror:0.28125
# [65]#011train-merror:0.31510#011validation-merror:0.28125
# [66]#011train-merror:0.31510#011validation-merror:0.28125
# [67]#011train-merror:0.31510#011validation-merror:0.28125
# [68]#011train-merror:0.31510#011validation-merror:0.28125
# [69]#011train-merror:0.31510#011validation-merror:0.28125
# [70]#011train-merror:0.31510#011validation-merror:0.28125
# [71]#011train-merror:0.31510#011validation-merror:0.28125
# [72]#011train-merror:0.31510#011validation-merror:0.28125
# [73]#011train-merror:0.31510#011validation-merror:0.28125
# [74]#011train-merror:0.31510#011validation-merror:0.28125
# [75]#011train-merror:0.31510#011validation-merror:0.28125
# [76]#011train-merror:0.31510#011validation-merror:0.28125
# [77]#011train-merror:0.31510#011validation-merror:0.28125
# [78]#011train-merror:0.31510#011validation-merror:0.28125
# [79]#011train-merror:0.31510#011validation-merror:0.28125
# [80]#011train-merror:0.31510#011validation-merror:0.28125
# [81]#011train-merror:0.31510#011validation-merror:0.28125
# [82]#011train-merror:0.31510#011validation-merror:0.28125
# [83]#011train-merror:0.31510#011validation-merror:0.28125
# [84]#011train-merror:0.31510#011validation-merror:0.28125
# [85]#011train-merror:0.31510#011validation-merror:0.28125
# [86]#011train-merror:0.31510#011validation-merror:0.28125
# [87]#011train-merror:0.31510#011validation-merror:0.28125
# [88]#011train-merror:0.31510#011validation-merror:0.28125
#
# 2022-01-29 12:08:56 Uploading - Uploading generated training model
# 2022-01-29 12:08:56 Completed - Training job completed
# Training seconds: 65
# Billable seconds: 65
# ____Finish running xgboost-loan-model-2-2022-01-29-12-05-31-003

# %% [markdown]
# ## Deploy the models in AWS web console
