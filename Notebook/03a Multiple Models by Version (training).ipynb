# %% [markdown]
# # Multiple Models by Versions
#
# ## Training models
#
# Previous activity: preparing and splitting data

# %%
import numpy as np
import pandas as pd
import sagemaker
from sagemaker import get_execution_role
from sagemaker.serializers import CSVSerializer

# %%
# Set the file directories
bucket_name = "sagemaker-loan-classification"
prefix = "xgboost"

# Set input and output paths for sagemaker
input_train = sagemaker.TrainingInput(
    s3_data=f"s3://{bucket_name}/{prefix}/train", content_type="csv")
input_test = sagemaker.TrainingInput(
    s3_data=f"s3://{bucket_name}/{prefix}/test", content_type="csv")
output_path = f"s3://{bucket_name}/{prefix}/saved_model"

# %%
# Build the estimator
def xgboost_fit_ver(version, use_spot_instances=False, max_run=3200, max_wait=None):
    name = f"xgboost-loan-{version.replace('.', '-')}" # Pay attention the quote marks. 
    print(f"____Running {name}")

    # Set checkpoint
    checkpoint = None
    if use_spot_instances == True:
        checkpoint = f"s3://{bucket_name}/{prefix}/checkpoints/{name}"
        print(f"___The checkpoint is saved to: {checkpoint}")
        max_wait = 7600

    # Set the container based on the version
    container = sagemaker.image_uris.retrieve("xgboost",
                                              sagemaker.Session().boto_region_name,
                                              version=version)

    xgb = sagemaker.estimator.Estimator(
        image_uri=container,
        role=sagemaker.get_execution_role(),
        instance_count=1,
        instance_type="ml.m5.xlarge",
        output_path=output_path,
        sagemaker_session=sagemaker.Session(),
        checkpoint_s3_uri=checkpoint,
        use_spot_instances=use_spot_instances,
        max_run=max_run,
        max_wait=max_wait,
        base_job_name=name,
    )

    # Set the hyperparameters
    xgb.set_hyperparameters(
        colsample_bytree=0.478,
        gamma=2.387,
        eta=0.175,
        max_depth=15,
        min_child_weight=7,
        num_round=86,
        subsample=0.80,
        num_class=2,
        objective="multi:softmax",
    )

    # Fit the model
    xgb.fit(
        {
            "train": input_train,
            "validation": input_test
        }
    )

    print(f"____Finish running {xgb.latest_training_job.name}")

# %%
# Train Xgboost version 0.90-1
xgboost_fit_ver(version="0.90-1", use_spot_instances=False)
# Out:
# ____Running xgboost-loan-0-90-1
# 2022-01-29 10:28:57 Starting - Starting the training job...
# 2022-01-29 10:29:20 Starting - Launching requested ML instancesProfilerReport-1643452137: InProgress
# ......
# 2022-01-29 10:30:20 Starting - Preparing the instances for training......
# 2022-01-29 10:31:26 Downloading - Downloading input data...
# 2022-01-29 10:31:42 Training - Downloading the training image..INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value multi:softmax to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# [10:32:05] 384x13 matrix with 4992 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# INFO:root:Determined delimiter of CSV input is ','
# [10:32:05] 96x13 matrix with 1248 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# INFO:root:Single node training.
# INFO:root:Train matrix has 384 rows
# INFO:root:Validation matrix has 96 rows
# [0]#011train-merror:0.177083#011validation-merror:0.25
# [1]#011train-merror:0.236979#011validation-merror:0.28125
# [2]#011train-merror:0.1875#011validation-merror:0.25
# [3]#011train-merror:0.177083#011validation-merror:0.25
# [4]#011train-merror:0.177083#011validation-merror:0.25
# [5]#011train-merror:0.177083#011validation-merror:0.25
# [6]#011train-merror:0.177083#011validation-merror:0.25
# [7]#011train-merror:0.177083#011validation-merror:0.25
# [64]#011train-merror:0.177083#011validation-merror:0.25
# [65]#011train-merror:0.177083#011validation-merror:0.25
# [66]#011train-merror:0.177083#011validation-merror:0.25
# [67]#011train-merror:0.177083#011validation-merror:0.25
# [68]#011train-merror:0.177083#011validation-merror:0.25
# [69]#011train-merror:0.177083#011validation-merror:0.25
# [70]#011train-merror:0.177083#011validation-merror:0.25
# [71]#011train-merror:0.177083#011validation-merror:0.25
# [72]#011train-merror:0.177083#011validation-merror:0.25
# [73]#011train-merror:0.177083#011validation-merror:0.25
# [74]#011train-merror:0.177083#011validation-merror:0.25
# [75]#011train-merror:0.177083#011validation-merror:0.25
# [76]#011train-merror:0.177083#011validation-merror:0.25
# [77]#011train-merror:0.177083#011validation-merror:0.25
# [78]#011train-merror:0.177083#011validation-merror:0.25
# [79]#011train-merror:0.177083#011validation-merror:0.25
# [80]#011train-merror:0.177083#011validation-merror:0.25
# [81]#011train-merror:0.177083#011validation-merror:0.25
# [82]#011train-merror:0.177083#011validation-merror:0.25
# [83]#011train-merror:0.177083#011validation-merror:0.25
# [84]#011train-merror:0.177083#011validation-merror:0.25
# [85]#011train-merror:0.177083#011validation-merror:0.25
#
# 2022-01-29 10:32:21 Uploading - Uploading generated training model
# 2022-01-29 10:32:21 Completed - Training job completed
# Training seconds: 51
# Billable seconds: 51
# ____Finish running xgboost-loan-0-90-1-2022-01-29-10-28-57-308

# %%
# Train Xgboost version 0.90-1
xgboost_fit_ver(version="1.3-1", use_spot_instances=False)
# Out:
# ____Running xgboost-loan-1-3-1
# 2022-01-29 10:33:18 Starting - Starting the training job...
# 2022-01-29 10:33:48 Starting - Launching requested ML instancesProfilerReport-1643452398: InProgress
# ......
# 2022-01-29 10:34:48 Starting - Preparing the instances for training......
# 2022-01-29 10:35:48 Downloading - Downloading input data
# 2022-01-29 10:35:48 Training - Downloading the training image....[2022-01-29 10:36:22.330 ip-10-0-178-238.ap-southeast-1.compute.internal:1 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-01-29:10:36:22:INFO] Imported framework sagemaker_xgboost_container.training
# [2022-01-29:10:36:22:INFO] Failed to parse hyperparameter objective value multi:softmax to Json.
# Returning the value itself
# [2022-01-29:10:36:22:INFO] No GPUs detected (normal if no gpus installed)
# [2022-01-29:10:36:22:INFO] Running XGBoost Sagemaker in algorithm mode
# [2022-01-29:10:36:22:INFO] Determined delimiter of CSV input is ','
# [2022-01-29:10:36:22:INFO] Determined delimiter of CSV input is ','
# [2022-01-29:10:36:22:INFO] Determined delimiter of CSV input is ','
# [2022-01-29:10:36:22:INFO] Determined delimiter of CSV input is ','
# [2022-01-29:10:36:22:INFO] Single node training.
# [2022-01-29:10:36:22:INFO] Train matrix has 384 rows and 13 columns
# [2022-01-29:10:36:22:INFO] Validation matrix has 96 rows
# [10:36:22] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softmax' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]#011train-mlogloss:0.64200#011validation-mlogloss:0.65923
# [1]#011train-mlogloss:0.62085#011validation-mlogloss:0.64113
# [2]#011train-mlogloss:0.59038#011validation-mlogloss:0.61854
# [3]#011train-mlogloss:0.56433#011validation-mlogloss:0.60159
# [4]#011train-mlogloss:0.54385#011validation-mlogloss:0.58854
# [5]#011train-mlogloss:0.52624#011validation-mlogloss:0.57957
# [6]#011train-mlogloss:0.51331#011validation-mlogloss:0.57295
# [7]#011train-mlogloss:0.50129#011validation-mlogloss:0.56724
# [8]#011train-mlogloss:0.49829#011validation-mlogloss:0.56793
# [9]#011train-mlogloss:0.49737#011validation-mlogloss:0.56663
# [10]#011train-mlogloss:0.49286#011validation-mlogloss:0.56698
# [11]#011train-mlogloss:0.48232#011validation-mlogloss:0.56384
# [12]#011train-mlogloss:0.47585#011validation-mlogloss:0.56202
# [13]#011train-mlogloss:0.46481#011validation-mlogloss:0.56033
# [14]#011train-mlogloss:0.46017#011validation-mlogloss:0.55775
# [15]#011train-mlogloss:0.45607#011validation-mlogloss:0.55749
# [16]#011train-mlogloss:0.44952#011validation-mlogloss:0.55769
# [17]#011train-mlogloss:0.44206#011validation-mlogloss:0.55545
# [18]#011train-mlogloss:0.43671#011validation-mlogloss:0.55424
# [19]#011train-mlogloss:0.43332#011validation-mlogloss:0.55590
# [20]#011train-mlogloss:0.43332#011validation-mlogloss:0.55599
# [21]#011train-mlogloss:0.43332#011validation-mlogloss:0.55595
# [22]#011train-mlogloss:0.42933#011validation-mlogloss:0.56060
# [23]#011train-mlogloss:0.42828#011validation-mlogloss:0.56054
# [24]#011train-mlogloss:0.42826#011validation-mlogloss:0.56033
# [25]#011train-mlogloss:0.42599#011validation-mlogloss:0.55844
# [26]#011train-mlogloss:0.42599#011validation-mlogloss:0.55842
# [27]#011train-mlogloss:0.42491#011validation-mlogloss:0.55946
# [28]#011train-mlogloss:0.42491#011validation-mlogloss:0.55948
# [29]#011train-mlogloss:0.42169#011validation-mlogloss:0.56199
# [30]#011train-mlogloss:0.41944#011validation-mlogloss:0.55920
# [31]#011train-mlogloss:0.41945#011validation-mlogloss:0.55909
# [32]#011train-mlogloss:0.41944#011validation-mlogloss:0.55927
# [33]#011train-mlogloss:0.41592#011validation-mlogloss:0.55982
# [34]#011train-mlogloss:0.41592#011validation-mlogloss:0.55977
# [35]#011train-mlogloss:0.41451#011validation-mlogloss:0.56005
# [36]#011train-mlogloss:0.41452#011validation-mlogloss:0.55995
# [37]#011train-mlogloss:0.41451#011validation-mlogloss:0.56007
# [38]#011train-mlogloss:0.41200#011validation-mlogloss:0.55897
# [39]#011train-mlogloss:0.41201#011validation-mlogloss:0.55891
# [40]#011train-mlogloss:0.41203#011validation-mlogloss:0.55878
# [41]#011train-mlogloss:0.41205#011validation-mlogloss:0.55870
# [42]#011train-mlogloss:0.41201#011validation-mlogloss:0.55888
# [43]#011train-mlogloss:0.40990#011validation-mlogloss:0.55709
# [44]#011train-mlogloss:0.40709#011validation-mlogloss:0.55973
# [45]#011train-mlogloss:0.40512#011validation-mlogloss:0.56067
# [46]#011train-mlogloss:0.40513#011validation-mlogloss:0.56076
# [47]#011train-mlogloss:0.40513#011validation-mlogloss:0.56082
# [48]#011train-mlogloss:0.40513#011validation-mlogloss:0.56084
# [49]#011train-mlogloss:0.40513#011validation-mlogloss:0.56076
# [50]#011train-mlogloss:0.40513#011validation-mlogloss:0.56079
# [51]#011train-mlogloss:0.40513#011validation-mlogloss:0.56084
# [52]#011train-mlogloss:0.40513#011validation-mlogloss:0.56051
# [53]#011train-mlogloss:0.40513#011validation-mlogloss:0.56050
# [54]#011train-mlogloss:0.40517#011validation-mlogloss:0.56024
# [55]#011train-mlogloss:0.40514#011validation-mlogloss:0.56039
# [56]#011train-mlogloss:0.40513#011validation-mlogloss:0.56052
# [57]#011train-mlogloss:0.40513#011validation-mlogloss:0.56049
# [58]#011train-mlogloss:0.40512#011validation-mlogloss:0.56062
# [59]#011train-mlogloss:0.40512#011validation-mlogloss:0.56067
# [60]#011train-mlogloss:0.40513#011validation-mlogloss:0.56086
# [61]#011train-mlogloss:0.40512#011validation-mlogloss:0.56067
# [62]#011train-mlogloss:0.40513#011validation-mlogloss:0.56054
# [63]#011train-mlogloss:0.40514#011validation-mlogloss:0.56039
# [64]#011train-mlogloss:0.40514#011validation-mlogloss:0.56037
# [65]#011train-mlogloss:0.40516#011validation-mlogloss:0.56026
# [66]#011train-mlogloss:0.40515#011validation-mlogloss:0.56031
# [67]#011train-mlogloss:0.40513#011validation-mlogloss:0.56047
# [68]#011train-mlogloss:0.40514#011validation-mlogloss:0.56040
# [69]#011train-mlogloss:0.40514#011validation-mlogloss:0.56041
# [70]#011train-mlogloss:0.40513#011validation-mlogloss:0.56054
# [71]#011train-mlogloss:0.40512#011validation-mlogloss:0.56064
# [72]#011train-mlogloss:0.40512#011validation-mlogloss:0.56071
# [73]#011train-mlogloss:0.40513#011validation-mlogloss:0.56073
# [74]#011train-mlogloss:0.40328#011validation-mlogloss:0.55975
# [75]#011train-mlogloss:0.40328#011validation-mlogloss:0.55965
# [76]#011train-mlogloss:0.40328#011validation-mlogloss:0.55958
# [77]#011train-mlogloss:0.40329#011validation-mlogloss:0.55982
# [78]#011train-mlogloss:0.40329#011validation-mlogloss:0.55990
# [79]#011train-mlogloss:0.40049#011validation-mlogloss:0.56028
# [80]#011train-mlogloss:0.40049#011validation-mlogloss:0.56008
# [81]#011train-mlogloss:0.40049#011validation-mlogloss:0.56020
# [82]#011train-mlogloss:0.40049#011validation-mlogloss:0.56021
# [83]#011train-mlogloss:0.39601#011validation-mlogloss:0.56499
# [84]#011train-mlogloss:0.39464#011validation-mlogloss:0.56178
# [85]#011train-mlogloss:0.39464#011validation-mlogloss:0.56179
#
# 2022-01-29 10:36:49 Uploading - Uploading generated training model
# 2022-01-29 10:36:49 Completed - Training job completed
# Training seconds: 60
# Billable seconds: 60
# ____Finish running xgboost-loan-1-3-1-2022-01-29-10-33-18-552

# %% [markdown]
# ## Deploy the models in web console

# %%
# Delete the endpoints if not needed anymore.
# xgb_model.delete_endpoint()
